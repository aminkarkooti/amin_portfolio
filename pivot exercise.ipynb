# %%
import os
os.chdir('c:\\users\\amink\\desktop\\Pandas_demo')
import pandas as pd
import numpy as np

# %%
      
url=r'c:\users\amink\desktop\Pandas_demo\exercise\titanic.csv'
df=pd.read_csv(url)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  Unnamed: 15  0 non-null      float64
# dtypes: bool(2), float64(3), int64(4), object(7)
# memory usage: 99.3+ KB

# %%
df.drop(columns='Unnamed: 15', inplace=True)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        Unnamed: 15
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Write a Pandas program to create a Pivot table and find the probability of survival by class, gender, solo boarding and port of embarkation.

# %%
result = df.pivot_table(index=['sex' , 'class' ],columns=[ 'embark_town','alone'  ],values='survived',aggfunc='count',fill_value=0)

# %%
result
# Out:
# embark_town   Cherbourg      Queenstown      Southampton
# alone             False True      False True       False True
# sex    class
# female First         25   18          1    0          34   14
#        Second         5    2          0    2          39   28
#        Third         18    5          8   25          58   30
# male   First         19   23          1    0          27   52
#        Second         6    4          0    1          30   67
#        Third         10   33         10   29          63  202

# %%
df.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
# Write a Pandas program to create a Pivot table and separate the gender according to whether they traveled alone or not to get the probability of survival.

# %%
result2=df.pivot_table(index=['sex'],columns=['alone'],values='survived',aggfunc='count',fill_value=0)

# %%
result2
# Out:
# alone   False  True
# sex
# female    188   126
# male      166   411

# %%
# Write a Pandas program to create a Pivot table and find number of adult male, adult female and children.

# %%
result3=df.pivot_table(index=['sex'],columns=['who'],values='alive',aggfunc='count')
result3

# %%
# Out:
# who     child    man  woman
# sex
# female   43.0    NaN  271.0
# male     40.0  537.0    NaN

# %%
# Write a Pandas program to create a Pivot table and check missing values of children.

# %%
result4= df.loc[df['who']=='child'].isnull().sum()
result4
# Out:
# survived        0
# pclass          0
# sex             0
# age             0
# sibsp           0
# parch           0
# fare            0
# embarked        0
# class           0
# who             0
# adult_male      0
# deck           70
# embark_town     0
# alive           0
# alone           0
# dtype: int64

# %%
df[df['who']=='child'].head(10)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 22         1       3  female  15.0      0      0   8.0292        Q   Third
# 24         0       3  female   8.0      3      1  21.0750        S   Third
# 39         1       3  female  14.0      1      0  11.2417        C   Third
# 43         1       2  female   3.0      1      2  41.5792        C  Second
# 50         0       3    male   7.0      4      1  39.6875        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# ...

# %%
#Write a Pandas program to create a Pivot table and calculate how many women and men were in a particular cabin class. G

# %%
result5= df.pivot_table(index=['sex'],columns=['pclass'],values='alive',aggfunc='count')
result5
# Out:
# pclass    1    2    3
# sex
# female   94   76  144
# male    122  108  347

# %%
#Write a Pandas program to create a Pivot table and compute survival totals of all classes along each group.

# %%
result6= df.pivot_table(index=['who'],columns=['pclass'],values='alive',aggfunc='count')
result6
# Out:
# pclass    1   2    3
# who
# child     6  19   58
# man     119  99  319
# woman    91  66  114

# %%
#Write a Pandas program to create a Pivot table and find survival of both gender and class affected.

# %%
result7= df.pivot_table(index=['sex'],columns=['class'],values='alive',aggfunc='count')
result7
# Out:
# class   First  Second  Third
# sex
# female     94      76    144
# male      122     108    347

# %%
result7_1 = df.groupby(['sex', 'class'])['survived'].aggregate('mean').unstack()
print(result7_1)
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
df[df['alive']=='no']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df['alive']=='yes']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#    Write a Pandas program to create a Pivot table 
#and find survival rate by gender, age of the different categories of various classes. Add the 
#fare as a dimension of columns and partition fare column into 2 categories based on the values present in fare columns.

# %%
fare1 = pd.cut(df['fare'], [0,30,100,200,513])
age1 = pd.cut(df['age'], [0, 10, 30, 60, 80])

result9= df.pivot_table(index=['sex',age1],columns=[fare1,'class'],values='survived')
result9
# Out:
# fare            (0, 30]                     (30, 100]                   \
# class             First    Second     Third     First Second     Third
# sex    age
# female (0, 10]      NaN  1.000000  0.588235       NaN    1.0  0.200000
#        (10, 30]     1.0  0.909091  0.537037  1.000000    1.0  0.000000
#        (30, 60]     0.8  0.888889  0.294118  1.000000    1.0  0.200000
#        (60, 80]     NaN       NaN  1.000000  1.000000    NaN       NaN
# male   (0, 10]      NaN  1.000000  0.500000  1.000000    1.0  0.125000
#        (10, 30]     0.5  0.027778  0.133803  0.538462    0.0  0.142857
#        (30, 60]     0.5  0.100000  0.098592  0.382353    0.0  0.666667
#        (60, 80]     0.2  0.333333  0.000000  0.000000    NaN       NaN
#
# fare            (100, 200] (200, 513]
# class                First      First
# sex    age
# female (0, 10]    0.000000        NaN
#        (10, 30]   0.833333        1.0
#        (30, 60]   1.000000        1.0
# ...

# %%
df['fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
url=r'c:\users\amink\desktop\Pandas_demo\exercise\SaleData.xlsx'
df1=pd.read_excel(url)

# %%
df1
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       45 non-null     float64
#  6   Unit_price  45 non-null     float64
#  7   Sale_amt    45 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 2.9+ KB

# %%
#  Write a Pandas program
# to create a Pivot table and find the total sale amount region wise,
# manager wise, sales man wise where Manager = "Douglas".

# %%
result11= df1.pivot_table(index=['Region','Manager','SalesMan'],values='Sale_amt')#,aggfunc='sum')
result11
# Out:
#                                Sale_amt
# Region  Manager SalesMan
# Central Douglas John       41338.666667
#         Hermann Luis       41274.600000
#                 Shelli      8424.500000
#                 Sigal      41679.166667
#         Martha  Steven     49922.500000
#         Timothy David      28191.000000
# East    Douglas Karen      16068.000000
#         Martha  Alexander  29587.875000
#                 Diana      18050.000000
# West    Douglas Michael    33418.000000
#         Timothy Stephen    22015.750000

# %%
table = pd.pivot_table(df1,index=["Region","Manager","SalesMan"], values="Sale_amt")
print(table.query('Manager == ["Douglas"]'))
# Out:
#                               Sale_amt
# Region  Manager SalesMan
# Central Douglas John      41338.666667
# East    Douglas Karen     16068.000000
# West    Douglas Michael   33418.000000

# %%
# Write a Pandas program to create a Pivot table and find the total sale amount region wise, manager wise, sales man wise.

# %%
result12= df1.pivot_table(index=['Region','Manager','SalesMan'],values='Sale_amt',aggfunc='sum')
result12
# Out:
#                            Sale_amt
# Region  Manager SalesMan
# Central Douglas John       124016.0
#         Hermann Luis       206373.0
#                 Shelli      33698.0
#                 Sigal      125037.5
#         Martha  Steven     199690.0
#         Timothy David      140955.0
# East    Douglas Karen       48204.0
#         Martha  Alexander  236703.0
#                 Diana       36100.0
# West    Douglas Michael     66836.0
#         Timothy Stephen     88063.0
